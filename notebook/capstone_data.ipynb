# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#complications_df = pd.read_csv('..\data\Complications_and_Deaths_capstonecsv.csv')

# %%
#tn = complications_df[complications_df["State"]=='TN']

# %%
#nash_tn_complications = tn[tn["City/Town"]=='NASHVILLE']

# %% [markdown]
# Data showing deaths amoung inpatients with complications after sx

# %%
#treatable_deaths = nash_tn_complications[nash_tn_complications["Measure ID"]=='PSI_04']

# %%
#ser_com = nash_tn_complications[nash_tn_complications["Measure ID"]=='PSI_90']

# %% [markdown]
# Data showing number of accidental cuts or tears from medical treatment

# %%
#accident_cuts = nash_tn_complications[nash_tn_complications["Measure ID"]=='PSI_15']

# %% [markdown]
# Data showing blood infections after sx

# %%
#blood_inf = nash_tn_complications[nash_tn_complications["Measure ID"]=='PSI_13']

# %%
readmin_df = pd.read_csv('..\data\data_readmin_capstonecsv.csv')
readmin_df
# Out:
#     facility_id                             facility_name  \
# 0        440006            TRISTAR SKYLINE MEDICAL CENTER
# 1        440006            TRISTAR SKYLINE MEDICAL CENTER
# 2        440006            TRISTAR SKYLINE MEDICAL CENTER
# 3        440006            TRISTAR SKYLINE MEDICAL CENTER
# 4        440006            TRISTAR SKYLINE MEDICAL CENTER
# ..          ...                                       ...
# 107      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 108      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 109      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 110      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 111      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                  address   citytown state  zip_code countyparish  \
# 0    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 1    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 2    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# ...

# %%
tn_readmin = readmin_df[readmin_df["state"]=='TN']
tn_readmin
# Out:
#     facility_id                             facility_name  \
# 0        440006            TRISTAR SKYLINE MEDICAL CENTER
# 1        440006            TRISTAR SKYLINE MEDICAL CENTER
# 2        440006            TRISTAR SKYLINE MEDICAL CENTER
# 3        440006            TRISTAR SKYLINE MEDICAL CENTER
# 4        440006            TRISTAR SKYLINE MEDICAL CENTER
# ..          ...                                       ...
# 107      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 108      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 109      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 110      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 111      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                  address   citytown state  zip_code countyparish  \
# 0    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 1    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 2    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# ...

# %%
nash_tn_readmin = tn_readmin[tn_readmin["citytown"]=='NASHVILLE']
nash_tn_readmin
# Out:
#     facility_id                             facility_name  \
# 0        440006            TRISTAR SKYLINE MEDICAL CENTER
# 1        440006            TRISTAR SKYLINE MEDICAL CENTER
# 2        440006            TRISTAR SKYLINE MEDICAL CENTER
# 3        440006            TRISTAR SKYLINE MEDICAL CENTER
# 4        440006            TRISTAR SKYLINE MEDICAL CENTER
# ..          ...                                       ...
# 107      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 108      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 109      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 110      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 111      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                  address   citytown state  zip_code countyparish  \
# 0    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 1    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 2    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# ...

# %% [markdown]
# Data showing rate of readmission by hospital in percentages

# %%
rate_readmin = nash_tn_readmin[nash_tn_readmin["measure_id"]=='READM_30_HOSP_WIDE']
rate_readmin
# Out:
#     facility_id                             facility_name  \
# 12       440006            TRISTAR SKYLINE MEDICAL CENTER
# 26       440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 40       440082           ASCENSION SAINT THOMAS HOSPITAL
# 54       440111          METRO NASHVILLE GENERAL HOSPITAL
# 68       440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 82       44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 96       440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 110      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 12           3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 26     1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 40   4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 54            1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 68         2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %%
rate_readmin_drop = rate_readmin.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'measure_id', 'compared_to_national', 'denominator', 'lower_estimate', 'higher_estimate','number_of_patients', 'number_of_patients_returned', 'footnote', 'start_date', 'end_date' ], axis=1)
rate_readmin_drop
# Out:
#                                 facility_name  \
# 12             TRISTAR SKYLINE MEDICAL CENTER
# 26       VANDERBILT UNIVERSITY MEDICAL CENTER
# 40            ASCENSION SAINT THOMAS HOSPITAL
# 54           METRO NASHVILLE GENERAL HOSPITAL
# 68          TRISTAR CENTENNIAL MEDICAL CENTER
# 82      VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 96      TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 110  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                           measure_name score
# 12   Rate of readmission after discharge from hospi...  15.9
# 26   Rate of readmission after discharge from hospi...  14.6
# 40   Rate of readmission after discharge from hospi...  14.4
# 54   Rate of readmission after discharge from hospi...  14.9
# 68   Rate of readmission after discharge from hospi...  14.9
# 82   Rate of readmission after discharge from hospi...  17.8
# 96   Rate of readmission after discharge from hospi...  14.8
# ...

# %%
rate_readmin_drop['Percent'] = rate_readmin_drop['score'].astype(str) + '%'
rate_readmin_drop
# Out:
#                                 facility_name  \
# 12             TRISTAR SKYLINE MEDICAL CENTER
# 26       VANDERBILT UNIVERSITY MEDICAL CENTER
# 40            ASCENSION SAINT THOMAS HOSPITAL
# 54           METRO NASHVILLE GENERAL HOSPITAL
# 68          TRISTAR CENTENNIAL MEDICAL CENTER
# 82      VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 96      TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 110  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                           measure_name score Percent
# 12   Rate of readmission after discharge from hospi...  15.9   15.9%
# 26   Rate of readmission after discharge from hospi...  14.6   14.6%
# 40   Rate of readmission after discharge from hospi...  14.4   14.4%
# 54   Rate of readmission after discharge from hospi...  14.9   14.9%
# 68   Rate of readmission after discharge from hospi...  14.9   14.9%
# 82   Rate of readmission after discharge from hospi...  17.8   17.8%
# ...

# %%
df7 = pd.DataFrame(rate_readmin_drop)
df7.to_csv('rate_readmin_drop.csv', index=False)

# %% [markdown]
# Data showing unplanned hospitalvisits after outpatient sx

# %%
unplan_visit = nash_tn_readmin[nash_tn_readmin["measure_id"]=='OP_36']
unplan_visit
# Out:
#     facility_id                             facility_name  \
# 6        440006            TRISTAR SKYLINE MEDICAL CENTER
# 20       440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 34       440082           ASCENSION SAINT THOMAS HOSPITAL
# 48       440111          METRO NASHVILLE GENERAL HOSPITAL
# 62       440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 76       44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 90       440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 104      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 6            3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 20     1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 34   4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 48            1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 62         2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %%
unplan_visit_drop = unplan_visit.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'measure_id', 'compared_to_national', 'denominator', 'lower_estimate', 'higher_estimate','number_of_patients', 'number_of_patients_returned', 'footnote', 'start_date', 'end_date' ], axis=1)
unplan_visit_drop
# Out:
#                                 facility_name  \
# 6              TRISTAR SKYLINE MEDICAL CENTER
# 20       VANDERBILT UNIVERSITY MEDICAL CENTER
# 34            ASCENSION SAINT THOMAS HOSPITAL
# 48           METRO NASHVILLE GENERAL HOSPITAL
# 62          TRISTAR CENTENNIAL MEDICAL CENTER
# 76      VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 90      TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 104  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                           measure_name          score
# 6    Ratio of unplanned hospital visits after hospi...            1.2
# 20   Ratio of unplanned hospital visits after hospi...            0.7
# 34   Ratio of unplanned hospital visits after hospi...              1
# 48   Ratio of unplanned hospital visits after hospi...  Not Available
# 62   Ratio of unplanned hospital visits after hospi...            1.1
# 76   Ratio of unplanned hospital visits after hospi...  Not Available
# ...

# %%
unplan_visit_drop['Percent'] = unplan_visit_drop['score'].astype(str) + '%'
unplan_visit_drop
# Out:
#                                 facility_name  \
# 6              TRISTAR SKYLINE MEDICAL CENTER
# 20       VANDERBILT UNIVERSITY MEDICAL CENTER
# 34            ASCENSION SAINT THOMAS HOSPITAL
# 48           METRO NASHVILLE GENERAL HOSPITAL
# 62          TRISTAR CENTENNIAL MEDICAL CENTER
# 76      VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 90      TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 104  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                           measure_name          score  \
# 6    Ratio of unplanned hospital visits after hospi...            1.2
# 20   Ratio of unplanned hospital visits after hospi...            0.7
# 34   Ratio of unplanned hospital visits after hospi...              1
# 48   Ratio of unplanned hospital visits after hospi...  Not Available
# 62   Ratio of unplanned hospital visits after hospi...            1.1
# 76   Ratio of unplanned hospital visits after hospi...  Not Available
# ...

# %%
df8 = pd.DataFrame(unplan_visit_drop)
df8.to_csv('unplan_visit_drop.csv', index=False)

# %% [markdown]
# HAI dataset

# %%
#nash_tn_hai = pd.read_csv('..\data\HAIcsv.csv')

# %%
#hcahps_df = pd.read_csv('..\data\HCAHPS-State_capstonecsv.csv')

# %%
#tn_sat = hcahps_df[hcahps_df["State"]=='TN']

# %%
#info_df = pd.read_csv('..\data\Hospital_General_Information_capstonecsv.csv')

# %%
#tn_info = info_df[info_df["State"]=='TN']

# %%
#nash_tn_info = tn_info[tn_info["City/Town"]=='NASHVILLE']

# %%
care_df = pd.read_csv('..\data\Timely_and_Effective_Care-Hospital_capstonecsv.csv')
care_df
# Out:
#        Facility ID                     Facility Name  \
# 0            10001   SOUTHEAST HEALTH MEDICAL CENTER
# 1            10001   SOUTHEAST HEALTH MEDICAL CENTER
# 2            10001   SOUTHEAST HEALTH MEDICAL CENTER
# 3            10001   SOUTHEAST HEALTH MEDICAL CENTER
# 4            10001   SOUTHEAST HEALTH MEDICAL CENTER
# ...            ...                               ...
# 115621      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 115622      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 115623      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 115624      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 115625      670319  TRINITY REGIONAL HOSPITAL SACHSE
#
#                                    Address City/Town State  ZIP Code  \
# 0                   1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# 1                   1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# 2                   1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# ...

# %%
tn_care = care_df[care_df["State"]=='TN']
tn_care
# Out:
#       Facility ID                      Facility Name                Address  \
# 92827      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 92828      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 92829      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 92830      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 92831      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...           ...                                ...                    ...
# 95236      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 95237      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 95238      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 95239      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 95240      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
nash_tn_care = tn_care[tn_care["City/Town"]=='NASHVILLE']
nash_tn_care
# Out:
#       Facility ID                             Facility Name  \
# 92902      440006            TRISTAR SKYLINE MEDICAL CENTER
# 92903      440006            TRISTAR SKYLINE MEDICAL CENTER
# 92904      440006            TRISTAR SKYLINE MEDICAL CENTER
# 92905      440006            TRISTAR SKYLINE MEDICAL CENTER
# 92906      440006            TRISTAR SKYLINE MEDICAL CENTER
# ...           ...                                       ...
# 94747      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 94748      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 94749      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 94750      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 94751      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                    Address  City/Town State  ZIP Code County/Parish  \
# 92902  3441 DICKERSON PIKE  NASHVILLE    TN     37207      DAVIDSON
# 92903  3441 DICKERSON PIKE  NASHVILLE    TN     37207      DAVIDSON
# ...

# %% [markdown]
# Data looking at er volume

# %%
er_vol = nash_tn_care[nash_tn_care["Measure ID"]=='EDV']
er_vol
# Out:
#       Facility ID                             Facility Name  \
# 92902      440006            TRISTAR SKYLINE MEDICAL CENTER
# 93377      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 93852      440082           ASCENSION SAINT THOMAS HOSPITAL
# 94027      440111          METRO NASHVILLE GENERAL HOSPITAL
# 94402      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 94677      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 94727      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                            Address  City/Town State  ZIP Code County/Parish  \
# 92902          3441 DICKERSON PIKE  NASHVILLE    TN     37207      DAVIDSON
# 93377    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232      DAVIDSON
# 93852  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205      DAVIDSON
# 94027           1818 ALBION STREET  NASHVILLE    TN     37208      DAVIDSON
# 94402        2300 PATTERSON STREET  NASHVILLE    TN     37203      DAVIDSON
# ...

# %% [markdown]
# Data looking at patient going from er to being admitted

# %%
er_vol_drop = er_vol.drop(['Facility ID', 'Address', 'City/Town', 'State', 'ZIP Code', 'County/Parish', 'Telephone Number', 'Condition', 'Measure Name', 'Sample', 'Footnote', 'Start Date', 'End Date' ], axis=1)
er_vol_drop
# Out:
#                                   Facility Name Measure ID          Score
# 92902            TRISTAR SKYLINE MEDICAL CENTER        EDV           high
# 93377      VANDERBILT UNIVERSITY MEDICAL CENTER        EDV      very high
# 93852           ASCENSION SAINT THOMAS HOSPITAL        EDV      very high
# 94027          METRO NASHVILLE GENERAL HOSPITAL        EDV         medium
# 94402         TRISTAR CENTENNIAL MEDICAL CENTER        EDV      very high
# 94677     TRISTAR SOUTHERN HILLS MEDICAL CENTER        EDV           high
# 94727  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY        EDV  Not Available

# %%
df4 = pd.DataFrame(er_vol_drop)
df4.to_csv('er_vol_drop.csv', index=False)

# %%
#er_des = nash_tn_care[nash_tn_care["Measure ID"]=='ED_2_Strata_1']

# %% [markdown]
# Data showing percent patients that left er before being seen

# %%
er_time = nash_tn_care[nash_tn_care["Measure ID"]=='OP_22']
er_time
# Out:
#       Facility ID                             Facility Name  \
# 92910      440006            TRISTAR SKYLINE MEDICAL CENTER
# 93385      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 93860      440082           ASCENSION SAINT THOMAS HOSPITAL
# 94035      440111          METRO NASHVILLE GENERAL HOSPITAL
# 94410      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 94685      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 94735      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                            Address  City/Town State  ZIP Code County/Parish  \
# 92910          3441 DICKERSON PIKE  NASHVILLE    TN     37207      DAVIDSON
# 93385    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232      DAVIDSON
# 93860  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205      DAVIDSON
# 94035           1818 ALBION STREET  NASHVILLE    TN     37208      DAVIDSON
# 94410        2300 PATTERSON STREET  NASHVILLE    TN     37203      DAVIDSON
# ...

# %% [markdown]
# Time spent in er before going home

# %%
er_time_drop_percent = er_time.drop(['Facility ID', 'Address', 'City/Town', 'State', 'ZIP Code', 'County/Parish', 'Telephone Number', 'Condition', 'Measure ID', 'Sample', 'Footnote', 'Start Date', 'End Date' ], axis=1)
er_time_drop_percent
# Out:
#                                   Facility Name            Measure Name  \
# 92910            TRISTAR SKYLINE MEDICAL CENTER  Left before being seen
# 93385      VANDERBILT UNIVERSITY MEDICAL CENTER  Left before being seen
# 93860           ASCENSION SAINT THOMAS HOSPITAL  Left before being seen
# 94035          METRO NASHVILLE GENERAL HOSPITAL  Left before being seen
# 94410         TRISTAR CENTENNIAL MEDICAL CENTER  Left before being seen
# 94685     TRISTAR SOUTHERN HILLS MEDICAL CENTER  Left before being seen
# 94735  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  Left before being seen
#
#                Score
# 92910              2
# 93385              4
# 93860              3
# 94035              4
# 94410              1
# 94685              2
# 94735  Not Available

# %%
er_time_drop_percent['Percent'] = er_time_drop_percent['Score'].astype(str) + '%'

# %%
er_time_drop_percent
# Out:
#                                   Facility Name            Measure Name  \
# 92910            TRISTAR SKYLINE MEDICAL CENTER  Left before being seen
# 93385      VANDERBILT UNIVERSITY MEDICAL CENTER  Left before being seen
# 93860           ASCENSION SAINT THOMAS HOSPITAL  Left before being seen
# 94035          METRO NASHVILLE GENERAL HOSPITAL  Left before being seen
# 94410         TRISTAR CENTENNIAL MEDICAL CENTER  Left before being seen
# 94685     TRISTAR SOUTHERN HILLS MEDICAL CENTER  Left before being seen
# 94735  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  Left before being seen
#
#                Score         Percent
# 92910              2              2%
# 93385              4              4%
# 93860              3              3%
# 94035              4              4%
# 94410              1              1%
# 94685              2              2%
# 94735  Not Available  Not Available%

# %%
df5 = pd.DataFrame(er_time_drop_percent)
df5.to_csv('er_time_drop_percent.csv', index=False)

# %%
er_time_left = nash_tn_care[nash_tn_care["Measure ID"]=='OP_18c']
er_time_left
# Out:
#       Facility ID                             Facility Name  \
# 92908      440006            TRISTAR SKYLINE MEDICAL CENTER
# 93383      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 93858      440082           ASCENSION SAINT THOMAS HOSPITAL
# 94033      440111          METRO NASHVILLE GENERAL HOSPITAL
# 94408      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 94683      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 94733      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                            Address  City/Town State  ZIP Code County/Parish  \
# 92908          3441 DICKERSON PIKE  NASHVILLE    TN     37207      DAVIDSON
# 93383    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232      DAVIDSON
# 93858  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205      DAVIDSON
# 94033           1818 ALBION STREET  NASHVILLE    TN     37208      DAVIDSON
# 94408        2300 PATTERSON STREET  NASHVILLE    TN     37203      DAVIDSON
# ...

# %%
er_time_left_drop = er_time_left.drop(['Facility ID', 'Address', 'City/Town', 'State', 'ZIP Code', 'County/Parish', 'Telephone Number', 'Condition', 'Measure ID', 'Sample', 'Footnote', 'Start Date', 'End Date' ], axis=1)
er_time_left_drop
# Out:
#                                   Facility Name  \
# 92908            TRISTAR SKYLINE MEDICAL CENTER
# 93383      VANDERBILT UNIVERSITY MEDICAL CENTER
# 93858           ASCENSION SAINT THOMAS HOSPITAL
# 94033          METRO NASHVILLE GENERAL HOSPITAL
# 94408         TRISTAR CENTENNIAL MEDICAL CENTER
# 94683     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 94733  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                             Measure Name          Score
# 92908  Average (median) time patients spent in the em...            774
# 93383  Average (median) time patients spent in the em...            358
# 93858  Average (median) time patients spent in the em...            251
# 94033  Average (median) time patients spent in the em...            420
# 94408  Average (median) time patients spent in the em...            340
# 94683  Average (median) time patients spent in the em...            206
# 94733  Average (median) time patients spent in the em...  Not Available

# %%
import numpy as np

# %%
er_time_left_drop= er_time_left_drop.replace('Not Available',np.nan)

# %%
er_time_left_drop2= er_time_left_drop.fillna(0)

# %%
er_time_left_drop2['Score'].astype(int)/60
# Out:
# 92908    12.900000
# 93383     5.966667
# 93858     4.183333
# 94033     7.000000
# 94408     5.666667
# 94683     3.433333
# 94733     0.000000
# Name: Score, dtype: float64

# %%
er_time_left_drop
# Out:
#                                   Facility Name  \
# 92908            TRISTAR SKYLINE MEDICAL CENTER
# 93383      VANDERBILT UNIVERSITY MEDICAL CENTER
# 93858           ASCENSION SAINT THOMAS HOSPITAL
# 94033          METRO NASHVILLE GENERAL HOSPITAL
# 94408         TRISTAR CENTENNIAL MEDICAL CENTER
# 94683     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 94733  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                             Measure Name Score
# 92908  Average (median) time patients spent in the em...   774
# 93383  Average (median) time patients spent in the em...   358
# 93858  Average (median) time patients spent in the em...   251
# 94033  Average (median) time patients spent in the em...   420
# 94408  Average (median) time patients spent in the em...   340
# 94683  Average (median) time patients spent in the em...   206
# 94733  Average (median) time patients spent in the em...   NaN

# %%
 er_time_left_drop.sort_values(by=['Score'], ascending=False)
# Out:
#                                   Facility Name  \
# 92908            TRISTAR SKYLINE MEDICAL CENTER
# 94033          METRO NASHVILLE GENERAL HOSPITAL
# 93383      VANDERBILT UNIVERSITY MEDICAL CENTER
# 94408         TRISTAR CENTENNIAL MEDICAL CENTER
# 93858           ASCENSION SAINT THOMAS HOSPITAL
# 94683     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 94733  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                                             Measure Name Score
# 92908  Average (median) time patients spent in the em...   774
# 94033  Average (median) time patients spent in the em...   420
# 93383  Average (median) time patients spent in the em...   358
# 94408  Average (median) time patients spent in the em...   340
# 93858  Average (median) time patients spent in the em...   251
# 94683  Average (median) time patients spent in the em...   206
# 94733  Average (median) time patients spent in the em...   NaN

# %%
er_time_left_drop['Score'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 er_time_left_drop['Score'].astype(int)
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...

# %%
er_time_left_drop['Hours'] = er_time_left_drop['Score']/60
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# ...

# %%
er_time_left_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 92908 to 94733
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Facility Name  7 non-null      object
#  1   Measure Name   7 non-null      object
#  2   Score          7 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes

# %%
df6 = pd.DataFrame(er_time_left_drop)
df6.to_csv('er_time_left_drop.csv', index=False)

# %%
#hours = ['12.9', '5.7', '4.2', '7', '5.7', '3.4', 'NA']

# %%
nash_tn_survey = pd.read_csv('..\data\patient_surveycsv.csv')
nash_tn_survey
# Out:
#     facility_id                             facility_name  \
# 0        440006            TRISTAR SKYLINE MEDICAL CENTER
# 1        440006            TRISTAR SKYLINE MEDICAL CENTER
# 2        440006            TRISTAR SKYLINE MEDICAL CENTER
# 3        440006            TRISTAR SKYLINE MEDICAL CENTER
# 4        440006            TRISTAR SKYLINE MEDICAL CENTER
# ..          ...                                       ...
# 739      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 740      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 741      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 742      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 743      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                  address   citytown state  zip_code countyparish  \
# 0    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 1    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 2    3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# ...

# %%
clean_rating = nash_tn_survey[nash_tn_survey["hcahps_measure_id"]=='H_CLEAN_STAR_RATING']
clean_rating
# Out:
#     facility_id                             facility_name  \
# 76       440006            TRISTAR SKYLINE MEDICAL CENTER
# 169      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 262      440082           ASCENSION SAINT THOMAS HOSPITAL
# 355      440111          METRO NASHVILLE GENERAL HOSPITAL
# 448      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 541      44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 634      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 727      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 76           3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 169    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 262  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 355           1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 448        2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %%
clean_rating_drop = clean_rating.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'hcahps_answer_description', 'patient_survey_star_rating_footnote', 'hcahps_answer_percent', 'hcahps_answer_percent_footnote', 'hcahps_linear_mean_value', 'number_of_completed_surveys_footnote', 'survey_response_rate_percent', 'survey_response_rate_percent_footnote', 'start_date', 'end_date' ], axis=1)
clean_rating_drop
# Out:
#                                 facility_name    hcahps_measure_id  \
# 76             TRISTAR SKYLINE MEDICAL CENTER  H_CLEAN_STAR_RATING
# 169      VANDERBILT UNIVERSITY MEDICAL CENTER  H_CLEAN_STAR_RATING
# 262           ASCENSION SAINT THOMAS HOSPITAL  H_CLEAN_STAR_RATING
# 355          METRO NASHVILLE GENERAL HOSPITAL  H_CLEAN_STAR_RATING
# 448         TRISTAR CENTENNIAL MEDICAL CENTER  H_CLEAN_STAR_RATING
# 541     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM  H_CLEAN_STAR_RATING
# 634     TRISTAR SOUTHERN HILLS MEDICAL CENTER  H_CLEAN_STAR_RATING
# 727  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  H_CLEAN_STAR_RATING
#
#                hcahps_question patient_survey_star_rating  \
# 76   Cleanliness - star rating                          2
# 169  Cleanliness - star rating                          1
# 262  Cleanliness - star rating                          2
# 355  Cleanliness - star rating              Not Available
# 448  Cleanliness - star rating                          3
# ...

# %%
df9 = pd.DataFrame(clean_rating_drop)
df9.to_csv('clean_rating_drop.csv', index=False)

# %%
nash_tn_survey.head(50)
# Out:
#    facility_id                   facility_name              address  \
# 0       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 1       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 2       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 3       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 4       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 5       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 6       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 7       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 8       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 9       440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 10      440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 11      440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# 12      440006  TRISTAR SKYLINE MEDICAL CENTER  3441 DICKERSON PIKE
# ...

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# Rating for staff respoonsiveness

# %%
staff_res = nash_tn_survey[nash_tn_survey["hcahps_measure_id"]=='H_COMP_3_STAR_RATING']
staff_res
# Out:
#     facility_id                             facility_name  \
# 32       440006            TRISTAR SKYLINE MEDICAL CENTER
# 125      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 218      440082           ASCENSION SAINT THOMAS HOSPITAL
# 311      440111          METRO NASHVILLE GENERAL HOSPITAL
# 404      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 497      44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 590      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 683      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 32           3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 125    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 218  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 311           1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 404        2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %%
staff_res_drop = staff_res.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'hcahps_answer_description', 'patient_survey_star_rating_footnote', 'hcahps_answer_percent', 'hcahps_answer_percent_footnote', 'hcahps_linear_mean_value', 'number_of_completed_surveys_footnote', 'survey_response_rate_percent', 'survey_response_rate_percent_footnote', 'start_date', 'end_date' ], axis=1)
staff_res_drop
# Out:
#                                 facility_name     hcahps_measure_id  \
# 32             TRISTAR SKYLINE MEDICAL CENTER  H_COMP_3_STAR_RATING
# 125      VANDERBILT UNIVERSITY MEDICAL CENTER  H_COMP_3_STAR_RATING
# 218           ASCENSION SAINT THOMAS HOSPITAL  H_COMP_3_STAR_RATING
# 311          METRO NASHVILLE GENERAL HOSPITAL  H_COMP_3_STAR_RATING
# 404         TRISTAR CENTENNIAL MEDICAL CENTER  H_COMP_3_STAR_RATING
# 497     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM  H_COMP_3_STAR_RATING
# 590     TRISTAR SOUTHERN HILLS MEDICAL CENTER  H_COMP_3_STAR_RATING
# 683  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  H_COMP_3_STAR_RATING
#
#                         hcahps_question patient_survey_star_rating  \
# 32   Staff responsiveness - star rating                          2
# 125  Staff responsiveness - star rating                          4
# 218  Staff responsiveness - star rating                          3
# 311  Staff responsiveness - star rating              Not Available
# ...

# %%
df10 = pd.DataFrame(staff_res_drop)
df10.to_csv('staff_res_drop.csv', index=False)

# %%
discharge_rating = nash_tn_survey[nash_tn_survey["hcahps_measure_id"]=='H_COMP_7_STAR_RATING']
discharge_rating
# Out:
#     facility_id                             facility_name  \
# 62       440006            TRISTAR SKYLINE MEDICAL CENTER
# 155      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 248      440082           ASCENSION SAINT THOMAS HOSPITAL
# 341      440111          METRO NASHVILLE GENERAL HOSPITAL
# 434      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 527      44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 620      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 713      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 62           3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 155    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 248  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 341           1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 434        2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %%
discharge_rating_drop = discharge_rating.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'hcahps_answer_description', 'patient_survey_star_rating_footnote', 'hcahps_answer_percent', 'hcahps_answer_percent_footnote', 'hcahps_linear_mean_value', 'number_of_completed_surveys_footnote', 'survey_response_rate_percent', 'survey_response_rate_percent_footnote', 'start_date', 'end_date' ], axis=1)
discharge_rating_drop
# Out:
#                                 facility_name     hcahps_measure_id  \
# 62             TRISTAR SKYLINE MEDICAL CENTER  H_COMP_7_STAR_RATING
# 155      VANDERBILT UNIVERSITY MEDICAL CENTER  H_COMP_7_STAR_RATING
# 248           ASCENSION SAINT THOMAS HOSPITAL  H_COMP_7_STAR_RATING
# 341          METRO NASHVILLE GENERAL HOSPITAL  H_COMP_7_STAR_RATING
# 434         TRISTAR CENTENNIAL MEDICAL CENTER  H_COMP_7_STAR_RATING
# 527     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM  H_COMP_7_STAR_RATING
# 620     TRISTAR SOUTHERN HILLS MEDICAL CENTER  H_COMP_7_STAR_RATING
# 713  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  H_COMP_7_STAR_RATING
#
#                    hcahps_question patient_survey_star_rating  \
# 62   Care transition - star rating                          2
# 155  Care transition - star rating                          4
# 248  Care transition - star rating                          4
# 341  Care transition - star rating              Not Available
# ...

# %%
df11 = pd.DataFrame(discharge_rating_drop)
df11.to_csv('discharge_rating_drop.csv', index=False)

# %% [markdown]
# Overall hospital rating by patient survey

# %%
hos_rating = nash_tn_survey[nash_tn_survey["hcahps_measure_id"]=='H_HSP_RATING_STAR_RATING']
hos_rating
# Out:
#     facility_id                             facility_name  \
# 86       440006            TRISTAR SKYLINE MEDICAL CENTER
# 179      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 272      440082           ASCENSION SAINT THOMAS HOSPITAL
# 365      440111          METRO NASHVILLE GENERAL HOSPITAL
# 458      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 551      44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 644      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 737      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 86           3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 179    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 272  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 365           1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 458        2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %% [markdown]
# Data on patient recommending the hospital

# %%
hos_rating_drop = hos_rating.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'hcahps_answer_description', 'patient_survey_star_rating_footnote', 'hcahps_answer_percent', 'hcahps_answer_percent_footnote', 'hcahps_linear_mean_value', 'number_of_completed_surveys_footnote', 'survey_response_rate_percent', 'survey_response_rate_percent_footnote', 'start_date', 'end_date' ], axis=1)
hos_rating_drop
# Out:
#                                 facility_name         hcahps_measure_id  \
# 86             TRISTAR SKYLINE MEDICAL CENTER  H_HSP_RATING_STAR_RATING
# 179      VANDERBILT UNIVERSITY MEDICAL CENTER  H_HSP_RATING_STAR_RATING
# 272           ASCENSION SAINT THOMAS HOSPITAL  H_HSP_RATING_STAR_RATING
# 365          METRO NASHVILLE GENERAL HOSPITAL  H_HSP_RATING_STAR_RATING
# 458         TRISTAR CENTENNIAL MEDICAL CENTER  H_HSP_RATING_STAR_RATING
# 551     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM  H_HSP_RATING_STAR_RATING
# 644     TRISTAR SOUTHERN HILLS MEDICAL CENTER  H_HSP_RATING_STAR_RATING
# 737  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  H_HSP_RATING_STAR_RATING
#
#                            hcahps_question patient_survey_star_rating  \
# 86   Overall hospital rating - star rating                          2
# 179  Overall hospital rating - star rating                          4
# 272  Overall hospital rating - star rating                          3
# ...

# %%
df3 = pd.DataFrame(hos_rating_drop)
df3.to_csv('hos_rating_drop.csv', index=False)

# %%
hos_rating['patient_survey_star_rating'].sort_values(ascending=False)
# Out:
# 365    Not Available
# 737                5
# 179                4
# 458                4
# 644                4
# 272                3
# 551                3
# 86                 2
# Name: patient_survey_star_rating, dtype: object

# %%
patient_rec = nash_tn_survey[nash_tn_survey["hcahps_measure_id"]=='H_RECMND_STAR_RATING']
patient_rec
# Out:
#     facility_id                             facility_name  \
# 91       440006            TRISTAR SKYLINE MEDICAL CENTER
# 184      440039      VANDERBILT UNIVERSITY MEDICAL CENTER
# 277      440082           ASCENSION SAINT THOMAS HOSPITAL
# 370      440111          METRO NASHVILLE GENERAL HOSPITAL
# 463      440161         TRISTAR CENTENNIAL MEDICAL CENTER
# 556      44018F     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 649      440197     TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 742      440218  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
#
#                          address   citytown state  zip_code countyparish  \
# 91           3441 DICKERSON PIKE  NASHVILLE    TN     37207     DAVIDSON
# 184    1211 MEDICAL CENTER DRIVE  NASHVILLE    TN     37232     DAVIDSON
# 277  4220 HARDING RD, PO BOX 380  NASHVILLE    TN     37205     DAVIDSON
# 370           1818 ALBION STREET  NASHVILLE    TN     37208     DAVIDSON
# 463        2300 PATTERSON STREET  NASHVILLE    TN     37203     DAVIDSON
# ...

# %%
#patient_rec.to_csv('data/patientrecommend.csv')

# %%
df = pd.DataFrame(patient_rec)
df.to_csv('patient_rec.csv', index=False)

# %%
patient_rec_drop = patient_rec.drop(['facility_id', 'address', 'citytown', 'state', 'zip_code', 'countyparish', 'telephone_number', 'hcahps_answer_description', 'patient_survey_star_rating_footnote', 'hcahps_answer_percent', 'hcahps_answer_percent_footnote', 'hcahps_linear_mean_value', 'number_of_completed_surveys_footnote', 'survey_response_rate_percent', 'survey_response_rate_percent_footnote', 'start_date', 'end_date' ], axis=1)
patient_rec_drop
# Out:
#                                 facility_name     hcahps_measure_id  \
# 91             TRISTAR SKYLINE MEDICAL CENTER  H_RECMND_STAR_RATING
# 184      VANDERBILT UNIVERSITY MEDICAL CENTER  H_RECMND_STAR_RATING
# 277           ASCENSION SAINT THOMAS HOSPITAL  H_RECMND_STAR_RATING
# 370          METRO NASHVILLE GENERAL HOSPITAL  H_RECMND_STAR_RATING
# 463         TRISTAR CENTENNIAL MEDICAL CENTER  H_RECMND_STAR_RATING
# 556     VA MIDDLE TENNESSEE HEALTHCARE SYSTEM  H_RECMND_STAR_RATING
# 649     TRISTAR SOUTHERN HILLS MEDICAL CENTER  H_RECMND_STAR_RATING
# 742  SAINT THOMAS HOSPITAL FOR SPINAL SURGERY  H_RECMND_STAR_RATING
#
#                       hcahps_question patient_survey_star_rating  \
# 91   Recommend hospital - star rating                          2
# 184  Recommend hospital - star rating                          5
# 277  Recommend hospital - star rating                          4
# 370  Recommend hospital - star rating              Not Available
# ...

# %%
df2 = pd.DataFrame(patient_rec_drop)
df2.to_csv('patient_rec_drop.csv', index=False)

# %%
#patient_rec['patient_survey_star_rating'].sort_values(ascending=False)
